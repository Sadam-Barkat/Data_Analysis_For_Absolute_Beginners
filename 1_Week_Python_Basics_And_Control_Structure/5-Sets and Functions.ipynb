# %%
myset = {1,2,3,1}

print(type(myset))
# Out:
# <class 'set'>

# %%
print(myset)
# Out:
# {1, 2, 3}

# %%
myset2 = {3,2,1}

print(myset2)
# Out:
# {1, 2, 3}

# %% [markdown]
# ## True consider as 1
# ## False consider as 0

# %%
myset3 = {1,True}

print(myset3)
# Out:
# {1}

# %%
myset4 = {1,1}

print(myset3)
# Out:
# {1}

# %%
myset5 = {True}

print(myset3)
# Out:
# {1}

# %%
myset2 = {3,2,1}

print(len(myset2))
# Out:
# 3

# %%
myset2 = {3,2,1,"Ahmad"}

print(myset2)
# Out:
# {1, 2, 3, 'Ahmad'}

# %%
myset2 = {3,2,1}

for x in myset2:
  print(x)
# Out:
# 1
# 2
# 3

# %%
myset2 = {3,2,1}

print(4 not in  myset2)
# Out:
# True

# %%
user = input()
# Out:
# 4

# %%
myset1 = {1,2,3,4,5,6}

user = int(input())

myset1.add(user)

print(myset1)
# Out:
# 98
# {1, 2, 3, 4, 5, 6, 98}

# %%
print(myset1[3])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-329e0f588c9d> in <cell line: 1>()
# ----> 1 print(myset1[3])
#
# TypeError: 'set' object is not subscriptable

# %%
thisset = {"apple", "banana", "cherry"}
tropical = {"pineapple", "mango", "papaya"}

thisset.update(tropical)

print(thisset)
# Out:
# {'apple', 'banana', 'papaya', 'pineapple', 'cherry', 'mango'}

# %%
thisset = {"apple", "banana", "cherry"}

thisset.remove('apple')

print(thisset)
# Out:
# {'cherry', 'banana'}

# %%
thisset = {"banana", "cherry"}

thisset.discard('apple')

print(thisset)
# Out:
# {'cherry', 'banana'}

# %%
thisset = {"banana", "cherry"}

thisset.pop()

print(thisset)
# Out:
# {'banana'}

# %% [markdown]
# # Functions

# %%
def my_function():
  print("Hello World")
  print("Hello")
  print("Hello World")
  print("Hello")
  print("Hello World")
  print("Hello")

# %%
my_function()
# Out:
# Hello World
# Hello
# Hello World
# Hello
# Hello World
# Hello

# %%
def my_function(fname):
  print("Welcome " + fname + "\nHope you are doing well")

# %%
user = input()

my_function(user)
# Out:
# Ali
# Welcome Ali
# Hope you are doing well

# %%
def Add(number):
  num = number + number
  print("Addition of your number is : ",num)

# %%
user = int(input())

Add(user)
# Out:
# 5
# Addition of your number is :  10
