# %%
a = "1"
print(type(a))
# Out:
# <class 'str'>

# %%
#          0,1,2,3,4,5,6
my_list = [1,2,3,4,5,6,7]
my_list2 = ['a','b','c']
my_list3 = [1,2,3,'a','c','v']

print(type(my_list))
print(type(my_list2))
print(type(my_list3))
# Out:
# <class 'list'>
# <class 'list'>
# <class 'list'>

# %%
#          0,1,2,3,4
my_list = [1,2,3,4,5,6,7]
print(my_list[::-2])
# Out:
# [7, 5, 3, 1]

# %% [markdown]
# # If - else Conditions

# %%
a = 2200
b = 300

#   False
if a > b:
  print("a is greater than b")
else:
  print("b is greater than a")
# Out:
# a is greater than b

# %%
a = 33
b = 33

if b > a:
  print("b is greater than a")
elif a == b:
  print("a and b are equal")
# Out:
# a and b are equal

# %%
a = 220
b = 33

if b > a:
  print("b is greater than a")
elif a == b:
  print("a and b are equal")
else:
  print("a is greater thann b")
# Out:
# a is greater thann b

# %%
if a > b: print("a is greater than b")
# Out:
# a is greater than b

# %%
a = 2
b = 330
print("a is greater than b") if a > b else print('b is greater than a')
# Out:
# b is greater than a

# %% [markdown]
# # And

# %%
a = 200
b = 33
c = 500

if a < b or c  > a:
  print("True")
else:
  print("False")
# Out:
# True

# %% [markdown]
# # For Loop

# %%
my_list = [1,2,3,4,5,6,7]

for a in my_list:
  print(a)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7

# %%
#    01234
b = "Ahmad"
for n in b:
  print(n)
# Out:
# A
# h
# m
# a
# d

# %%
#       012345678
name = "Shaharyar"
print(name[6])
# Out:
# y

# %%
#      0 1 2 3 4
lst = [1,2,3,4,5]

print(lst[3])
# Out:
# 4
